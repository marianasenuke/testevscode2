# %% [markdown]
# # Atividade 4:

# %%
#Passeio aleatório (implementação básica):
import numpy as np
import matplotlib.pyplot as plt
import random
rng=np.random.default_rng()

def passeio_aleatorio(N, p):
    """
    """

N = 1000    
passos = rng.choice([-1,1], size= N, p= [0.6, 0.4])
posição: np.cumsum (passos)



# Primeiro subplot: p = 0.5
plt.figure(figsize = (10,8))
plt.subplot(1, 2, 1)
plt.plot(passeio1, color= "pink")
plt.title(f'Passeio Aleatório (p = {p1})')
plt.xlabel('Número de passos')
plt.ylabel('Posição')




# Segundo subplot: p = 0.8
plt.subplot(1, 2, 2)
plt.plot(passeio2,color="purple")
plt.title(f'Passeio Aleatório (p = {p2})')
plt.xlabel('Número de passos')
plt.ylabel('Posição')
# Out:
# Text(0, 0.5, 'Posição')
